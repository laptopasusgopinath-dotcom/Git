# %% [markdown]
# # Git

# %% [markdown]
# ## 1. Task to Be Performed:
# 1. Based on what you have learnt in the class, do the following steps:
#
#                  a. Create a new folder
#
#                  b. Put the following files in the folder
#
#
#                                     Code.txt
#
#                                     Log.txt
#
#                                     Output.txt
#
#
#                  c. Stage the Code.txt and Output.txt files
#
#                  d. Commit them
#
#                  e. And finally push them to GitHub
#
#
# 2. Please share the commands for the above points
#
#
# ## Answer-
#
# * a.  mkdir gitFolder
# * b. cd gitFolder
#        touch Code.txt Log.txt Output.txt
# * c.  git init
# git add Code.txt Output.txt
# * d. git commit -m "Code and Output is ready to push GitHub"
# * e. git remote add origin SSH or HTTPS path
# git branch -M main
# git push -u origin main

# %% [markdown]
# # 2. Tasks to Be Performed:
#
#
# 1. Create a Git working directory with feature1.txt and feature2.txt in the master branch
#
# 2. Create 3 branches develop, feature1 and feature2
#
# 3. In develop branch create develop.txt, do not stage or commit it
#
# 4. Stash this file and check out to feature1 branch
#
# 5. Create new.txt file in feature1 branch, stage and commit this file
#
# 6. Checkout to develop, unstash this file and commit
#
# 7. Please submit all the Git commands used to do the above steps
#
#
# # Answer -
#
# * 1. mkdir Git
# cd Git
# git init
# git branch -M master
# touch feature1.txt feature2.txt
#
# * 2. git branch develop
# git branch feature1
# git branch feature2
#
#
# * 3.  git status
# git checkout -b develop
# touch develop.txt
#
#
# * 4. git stash
# git checkout feature1
#
# * 5. touch new.txt
# git add .
# git commit -m "new file work fine"
#
# * 6. git checkout develop
# git stash pop
# git add .
# git commit -m "develop.txt file added after unstash"

# %% [markdown]
# # 3. Tasks to Be Performed:
#
#
# 1. Create a Git working directory, with the following branches:
#
#
#                Develop
#
#                F1
#
#                f2
#
#
# 2. In the master branch, commit main.txt file
#
# 3. Put develop.txt in develop branch, f1.txt and f2.txt in f1 and f2 respectively
#
# 4. Push all these branches to GitHub
#
# 5. On local delete f2 branch
#
# 6. Delete the same branch on GitHub as well.
#
#
# # Answer -
#
# * 1. mkdir Git
# cd Git
# git init
# git branch Develop
# git branch F1
# git branch f2
#
# * 2. git status
# touch main.txt
# git add main.txt
# git commit -m "main.txt wrok complete"
#
# * 3. git checkout Develop
# touch develop.txt
# git add develop.txt
# git commit -m "Add develop.txt"
# git checkout F1
# touch f1.txt
# git add f1.txt
# git commit -m "Add f1.txt"
# git checkout f2
# touch f2.txt
# git add f2.txt
# git commit -m "Add f2.txt"
#
#
# * 4. git checkout master
# git merge develop
# git merge F1
# git merge f2
#  git remote add origin SSH or HTTPS path
# git branch -M main
# git push -u origin main
#
#
# * 5. git branch -d f2
#
# * 6. git push origin --delete f2

# %% [markdown]
# # 4. Tasks to Be Performed:
#
# 1. Put master.txt on master branch, stage and commit
#
# 2. Create 3 branches: public 1, public 2 and private
#
# 3. Put public1.txt on public 1 branch, stage and commit
#
# 4. Merge public 1 on master branch
#
# 5. Merge public 2 on master branch
#
# 6. Edit master.txt on private branch, stage and commit
#
# 7. Now update branch public 1 and public 2 with new master code in private
#
# 8. Also update new master code on master
#
# 9. Finally update all the code on the private branch
#
#
# # Answer -
# * 1. mkdir Git
# cd Git
# git init
# touch master.txt
# git add .
# git commit -m "add master.txt"
#
# * 2. git branch public1
# git branch public2
# git branch private
#
# * 3. git status
# git checkout public1
# touch public1.txt
# git add .
# git commit -m "add public1.txt"
#
# * 4. git checkout master
# git merge public1
#
# * 5. git merge public2
#
# * 6. git checkout private
# (after edit)
# git add master.txt
# git commit -m "edit master.txt on private branch"
#
# * 7. git checkout public1
# git merge private
# (If conflict occurs, resolve it manually, then:)
# git add .
# git commit -m "Merge private into public1 (conflicts resolved)"
# git checkout public2
# git merge private
# (If conflict occurs, resolve it manually, then:)
# git add .
# git commit -m "Merge private into public2 (conflicts resolved)"
#
#
# * 8. git checkout master
# git merge private
# (Resolve conflicts if any)
# git add .
# git commit -m "Merge private into master (conflicts resolved)"
#
# * 9. git checkout private
# git merge master
# git merge public1
# git merge public2

# %% [markdown]
# # 5. Tasks to Be Performed:
#
# 1. Create a Git Flow workflow architecture on Git
#
# 2. Create all the required branches
#
# 3. starting from e feature branch, push the branch to the master, following the architecture
#
# 4. Push an urgent.txt on master using hotfix
#
#
# # Answer -
#
# * 1. mkdir GitFlowProject
# cd GitFlowProject
# git init
# touch README.md
# git add .
# git commit -m "Initial commit on master"
#
# * 2. git branch develop
# git branch feature
# git branch release
# git branch hotfix
#
# * 3. git checkout master
# git merge develop
# git merge feature
# git merge release
# git merge hotfix
#
# * 4. git checkout hotfix
# touch urgent.txt
# git add .
# git commit -m "urgent.txt add successfully"
# git checkout master
# git merge hotfix
